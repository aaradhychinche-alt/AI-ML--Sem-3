# %%
import pandas as pd

# %%
df = pd.read_csv('tip.csv')

# %% [markdown]
# # Selecting Columns

# %%
# selecting many coulumns 
x = df['sex']
print(x.shape)
y = df[['day','sex']]
print(y.shape)
print()
print(y)
# Out:
# (244,)
# (244, 2)
#
#       day     sex
# 0     Sun  Female
# 1     Sun    Male
# 2     Sun    Male
# 3     Sun    Male
# 4     Sun  Female
# ..    ...     ...
# 239   Sat    Male
# 240   Sat  Female
# 241   Sat    Male
# 242   Sat    Male
# 243  Thur  Female
#
# [244 rows x 2 columns]
